# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')
print(df.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.violinplot(x="day", y="total_bill", data=df)
plt.show()

# %%
sb.violinplot(x="day", y="total_bill", hue="sex", data=df)
plt.show()

# %%
import pandas as pd
import seaborn as sb
from scipy.stats import norm
from matplotlib import pyplot as plt
df = sb.load_dataset('iris')
sb.distplot(df['petal_length'],kde=True, hist=False, fit=norm,)
plt.show()
# Out:
#   File "<ipython-input-21-716302ae54d3>", line 6
#     sb.distplot(df['petal_length'],kde=True, hist=False, fit=norm,kind='hex)
#                                                                             ^
# SyntaxError: EOL while scanning string literal

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('iris')
sb.jointplot(x='petal_length',y='petal_width',data=df, kind="kde", color="G")
plt.show()

# %%
sb.set_style("ticks")
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]

sb.pairplot(df,hue='species',diag_kind="kde",kind="scatter",palette=flatui)
plt.show()

# %%
sb.stripplot(x="species", y="petal_length", data=df, jitter=True)
plt.show()

# %%
sb.swarmplot(x="species", y="petal_length", data=df)
plt.show()

# %%
sb.boxplot(x="species", y="petal_length", data=df)
plt.show()

# %%
from matplotlib import pyplot as plt
import seaborn as sb
current_palette = sb.color_palette("Reds", n_colors=4)
sb.palplot(current_palette)
plt.show()

# %%
def sinePlot(flip = 1):
    x = np.linspace(0,14,100)
    
    for i in range(1,5):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

sns.set_style("dark")
sns.set_palette("husl")
sinePlot(2)
plt.show()
